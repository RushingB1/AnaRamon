# %% [markdown]
# # Sistemas Inteligentes
#
# ## Curso académico 2024-2025
#
# ### Laboratorio 2: Búsqueda Metaheurística
#
# #### Instructores
#
# * Juan Carlos Alfaro Jiménez: JuanCarlos.Alfaro@uclm.es
# * María Julia Flores Gallego: Julia.Flores@uclm.es
# * Ismael García Varea: Ismael.Garcia@uclm.es
# * Adrián Rodríguez López: Adrian.Rodriguez18@alu.uclm.es
#
# #### Alumnos Grupo 1
# * Ana Barberá Villanueva: Ana.Barbera@alu.uclm.es
# * Ramón Ángel Aguilar Rodríguez : RamonAngel.Aguilar@alu.uclm.es

# %% [markdown]
# ## Estaciones de Servicio y Energía: Encontrando la Configuración Óptima

# %% [markdown]
# ## 1. Introducción
#
# ¡Noticias emocionantes! El **Ministerio de Transporte y Movilidad Sostenible** ha quedado muy impresionado con las soluciones desarrolladas en nuestro primer trabajo, la Práctica 1. Están particularmente interesados en implementar estos algoritmos en la planificación de rutas de vehículos autónomos, con A* como el método MÁS efectivo para identificar el camino óptimo de manera eficiente. Para avanzar en este proyecto, el Ministerio tiene como objetivo establecer estratégicamente estaciones de servicio en áreas urbanas para apoyar su flota de vehículos autónomos. Estas estaciones funcionarán como centros de flota y proporcionarán servicios esenciales para los vehículos.
#
# Para lograr esto, han solicitado **nuestra experiencia técnica para determinar la distribución óptima de estas estaciones** en los mapas de la ciudad. Sin embargo, no todas las intersecciones son elegibles como ubicación de una estación; el Ministerio ha preseleccionado intersecciones candidatas basándose en criterios específicos establecidos por sus equipos técnicos y administrativos. Su principal enfoque es la sostenibilidad y el acceso equitativo, con el objetivo de garantizar que todos los ciudadanos estén razonablemente cerca de una estación de servicio. Entre estos puntos seleccionados, solo se elegirá un número específico. Para facilitar nuestra tarea de determinar cuáles deben ser, han proporcionado datos sobre la cobertura poblacional de cada intersección candidata, lo que nos permite tener en cuenta tanto el acceso como la cobertura en nuestra estrategia de distribución.
#
# El objetivo principal es garantizar un acceso eficiente a la máxima población posible, manteniendo una distribución equilibrada en toda la ciudad, una consideración vital para un sistema de transporte completamente autónomo.

# %% [markdown]
# ### 1.1 Objetivos del Laboratorio
#
# En esta práctica, aplicaremos técnicas de búsqueda metaheurística para resolver problemas de optimización combinatoria.
#
# El primer objetivo es comprender la tarea y formularla desde la perspectiva de la búsqueda metaheurística. Implementaremos al menos dos algoritmos:
#
# * **Búsqueda Aleatoria**, como un punto de partida básico que generará múltiples soluciones, evaluará cada una y devolverá la mejor.
#
# * **Algoritmo Genético**, que permitirá configurar varios parámetros, como el tamaño de la población, la tasa de mutación y el número de generaciones, entre otros.
#
#
# Además, para la evaluación no-continua se tendrá que implementar la Ascensión de Cplinas o Hill Cilimbing (obligatoriamente), y opcionalmente implementar el algoritmo **Iterated Local Search** (ILS), ambos explicados en el Tema 7.
#
# A continuación, analizaremos y compararemos el rendimiento de estos algoritmos ejecutándolos en instancias de problemas de diferente complejidad.
#
# Esperamos que esta práctica te ayude a profundizar en tu comprensión de las técnicas metaheurísticas y te anime a considerar cómo se pueden aplicar en problemas reales de optimización combinatoria.
#
# **¡Buena suerte!**

# %% [markdown]
# ## 2. Descripción del Problema
#
# ### 2.1 Problemas de Entrada
#
# Cada escenario se proporcionará en un archivo en formato `json` que contiene la siguiente información, con el formato de un diccionario cuyas claves son:
#
# * `address`: La dirección utilizada.
# * `distance`: Radio máximo utilizado para definir intersecciones y segmentos alrededor de la dirección.
# * `intersections`: Una lista de diccionarios con información sobre las intersecciones.
# * `segments`: Una lista de diccionarios con información sobre los segmentos, que representan las calles entre dos intersecciones.
# * `candidates`: Una lista de pares (identificador, población) que contiene las intersecciones candidatas. Notad que los identificadores en esta lista deben estar incluidos en la lista de intersecciones.
# * `number_stations`: El número de estaciones de servicio que se deben ubicar, que no debe superar el número de candidatos.
#
# Cada diccionario en `intersections` incluye tres claves:
#
# * `identifier`: Identificador de la intersección
# * `longitude`: Longitud de la intersección
# * `latitude`: Latitud de la intersección
#
# Cada diccionario en `segments` incluye cuatro claves:
#
# * `origin`: Intersección de origen
# * `destination`: Intersección de destino
# * `distance`: Distancia entre las dos intersecciones
# * `speed`: Velocidad máxima permitida entre las dos intersecciones
#
# **IMPORTANTE**: `initial` y `final` ya no están incluidos en el archivo JSON, ya que no son necesarios. Durante la evaluación de una posible configuración, estos puntos iniciales y finales cambiarán varias veces. Esto puede requerir algunos ajustes en el código de la Práctica 1 para ejecutar A*. Estos cambios deben estar claramente indicados (tu código debe coincidir con el de la Práctica 1, excepto por estos cambios) y discutidos en la memoria de prácticas.

# %% [markdown]
# ### 2.2. Ejemplo ilustrativo
#
# Un posible ejemplo de este problema podría ser el que se muestra en la siguiente imagen, que representa una parte de la ciudad de Albacete:
#
# ![title](sample-problems-lab2/toy/example.png)
#
# En este caso, el número de estaciones de servicio de vehículos que se deben ubicar es 4, entre las 15 intersecciones candidatas representadas con puntos azules (etiquetadas con la población cubierta). Una posible solución se representa con puntos verdes.
#
# ---
#
# ##### Nota:
#
# * El archivo que contiene la imagen debe guardarse en la ruta indicada en el código de esta celda.
#
# ---

# %% [markdown]
# ### 2.3 Definición formal del problema
#
# Necesitamos elegir $s$ estaciones de entre $c$ intersecciones candidatas o elegibles, con $s<c$. Por lo tanto, nuestro objetivo es decidir en cuál de estas $c$ intersecciones candidatas debemos ubicar las $s$ estaciones de servicio de vehículos, de manera que se minimice el tiempo promedio de viaje que cada habitante tarda desde su hogar hasta la estación más cercana. Si denotamos por $S$ al vector de tamaño $s$ que contiene las intersecciones en las que se ubican las estaciones de vehículos y por $C$ al vector de intersecciones candidatas que contiene el par (id, pop) para cada intersección candidata, entonces formalmente, queremos resolver el siguiente problema de optimización:
#
# $$
# S^* = \arg\min_{S} \frac{1}{\sum_{i=0}^{c-1} C[i].pop} \cdot \min_{j=0,\dots,s-1} \left\{\sum_{i=0}^{c-1} \; C[i].pop \cdot time(C[i].id,S[j])\right\}
# $$
#
# donde:
# - $C[i].pop$ representa la población (número de habitantes) cubierta por la intersección candidata $i$.
# - $C[i].id$ es el identificador de la intersección candidata $i$.
# - $time(A,B)$ representa el menor tiempo real para viajar desde la intersección $A$ hasta la intersección $B$.
#
# Las siguientes consideraciones deben tenerse en cuenta respecto a la expresión anterior:
# - Estamos tratando con un problema de minimización.
# - La cardinalidad del espacio de búsqueda es:
#
# $$
# \binom{c}{s} = \frac{c!}{(c-s)!s!}
# $$
#
# por ejemplo, si tenemos 20 intersecciones elegibles y 4 estaciones de vehículos, el número de soluciones posibles es 210, no demasiadas; pero si tenemos 100 candidatos y 10 estaciones, entonces el número de soluciones posibles es $1.7\times10^{13}$ ($5.3\times 10^{20}$ con 20 estaciones).

# %% [markdown]
# ## 3. Desarrollo de la práctica
#
# Antes de implementar los algoritmos, primero debes considerar definir los elementos básicos en este tipo de problemas, a saber:
#
# - Una representación conveniente para las soluciones (configuraciones, cromosomas, individuos, ...) del problema que se utilizarán en los algoritmos de optimización combinatoria. Piensa detenidamente en las distintas opciones y tendrás que discutirlas en el informe de la tarea.
#
# - Implementar un mecanismo de evaluación para gestionar las evaluaciones realizadas por los algoritmos de optimización combinatoria. A continuación, se detallará cómo debe realizarse la evaluación.
#
# - Notas importantes:
#     - En el caso de que A* no devuelva ninguna solución (coste = inf), reemplazad este valor por un número muy alto en comparación con el tiempo máximo en nuestro problema. Reflexiona sobre la necesidad de esto y discútelo en el informe.
#     - Podéis aprovechar el mecanismo de evaluación para guardar algunos cálculos, recopilar estadísticas e imprimir los resultados.
#     - Tened en cuenta que esta tarea requiere que ya hayas resuelto la Práctica 1, y necesitarás reutilizar el código implementado para resolver esta práctica.
#
# Tendréis que resolver muchos problemas similares a los de la Práctica 1. Los mapas serán los mismos, pero los problemas necesitan incorporar nueva información, que es la lista de intersecciones candidatas y, para cada una de ellas, la población que cubren. El número de estaciones que se deben ubicar también se indica en el problema como `number_stations`.

# %% [markdown]
# ### 3.1 Evaluación de una solución
#
# Dada una instancia específica del problema a resolver, y asumiendo que $C$ denota su lista de intersecciones candidatas, el valor de cada posible solución $S$ debe calcularse como:
#
# $$value(S) = \frac{1}{\sum_{i=0}^{c-1} C[i].pop} \cdot \min_{j=0,\dots,s-1} \left\{\sum_{i=0}^{c-1} \; C[i].pop \cdot time(C[i].id,S[j])\right\}$$
#
# de acuerdo con la fórmula presentada en la sección 2.2.

# %% [markdown]
# ## 4. Plan de trabajo

# %% [markdown]
# ### 4.1. Tareas
#
# * Transferid y adaptad vuestro código de la Práctica 1 para resolver búsquedas con A* que necesitaréis aquí:
#     * Reutilizad la mayor parte del código necesario de vuestra Práctica 1.
#     * Describid qué se ha modificado, por qué y cómo.
#
# * Procesad los nuevos archivos JSON y guardad el problema de acuerdo con lo siguiente:
#     * Además de las clases de búsqueda (Problem_2, State, Action, ...), deberéis trabajar con las intersecciones candidatas.
#     * Construid un mecanismo capaz de almacenar y recuperar las intersecciones candidatas y la población asociada a cada una.
#
# * Representación de una posible configuración:
#     * Entre las vistas en el Tema 6, encontrad la representación más adecuada para este problema y adaptadla, teniendo en cuenta que cada problema tiene valores distintos para el número total de intersecciones, intersecciones elegibles y el número solicitado de estaciones.
#     * Conectadla a un método adecuado para evaluar cada una considerando las indicaciones mencionadas anteriormente en el punto 3.2.
#
# * Implementación de algoritmos:
#     * Implementad, al menos, los dos algoritmos requeridos (Búsqueda Aleatoria y un Algoritmo Genético — GA). Tened en cuenta que para la evaluación no continua, también deberéis agregar Hill Climbing y, opcionalmente, ILS.
#     * En el GA, aseguraos de haber implementado la generación de una población junto con los elementos principales dentro del bucle principal: selección, cruce, mutación y combinación de generaciones.
#
# * Experimentación y análisis:
#     * Los parámetros que se puedan ajustar deben ser explorados adecuadamente, también en relación con los problemas dados (dimensionalidad, complejidad, etc.).
#     * También deberéis estudiar el rendimiento resultante en términos de desempeño, convergencia, número de generaciones, etc.
#     * Comparad la Búsqueda Aleatoria y el Algoritmo Genético, asegurándoos de obtener resultados consistentes.
#
# * Informe:
#     * Redactad un informe detallando el proceso seguido, las estrategias implementadas y los resultados obtenidos, junto con gráficos y comparaciones visuales.

# %% [markdown]
# ### 4.2. Evaluación de la práctica
#
# En la modalidad de **evaluación continua**, la evaluación de la práctica se realizará a través de un examen individual en el que se tendrá en cuenta lo siguiente:
#
# * Definición e implementación correcta de la representación de la configuración y de la función de evaluación: 25%
# * Implementación correcta del algoritmo genético: 50%, que cubre
#     * El bucle general para las generaciones es correcto: 10%
#     * Los distintos operadores están correctamente diseñados y codificados: 40%
# * Eficiencia y optimización: 15%
# * Experimentación realizada y análisis de resultados: 10%
#
# Es necesario que la Práctica 1 esté correctamente integrada y que la Búsqueda Aleatoria funcione de manera consistente para que todos los estudiantes puedan utilizarla como un punto de partida base adecuado.
#
# Todo esto se ponderará según el nivel de conocimiento que el estudiante demuestre sobre la práctica en caso de que el examen sea una entrevista personal.
#
# En la modalidad de **evaluación no continua**, la evaluación se modificará como se indica a continuación:
#
# * Definición e implementación correcta de la representación de la configuración y de la función de evaluación: 15%
# * Implementación correcta del algoritmo genético: 40%, que cubre
#     * El bucle general para las generaciones es correcto: 7%
#     * Los distintos operadores están correctamente diseñados y codificados: 33%
# * Implementación correcta del algoritmo de Hill Climbing (obligatorio): 15%
# * Implementación correcta del algoritmo ILS (opcional): 5%
# * Eficiencia y optimización: 15%
# * Experimentación realizada y análisis de resultados: 10%

# %% [markdown]
# ### 4.3. Fechas importantes
#
# * Fecha límite para entregar el código: **13 de diciembre de 2024**.
# * Fecha límite para la entrega del informe: **Final del semestre**.

# %%
import json
from abc import ABC, abstractmethod
import heapq #priority queue
import time
import random
import logging #Imprimir archivo
EstadoDestino = None

# %%
class Estado:
    def __init__(self, interID, latitud, longitud):
        self.intersec = interID
        self.latitud = latitud
        self.longitud = longitud

    def __eq__(self, other): #equals
        return self.intersec == other.intersec

    def __lt__(self, other):  # less than
        return self.intersec < other.intersec

    def __hash__(self): #Identifica un objeto
        return hash(self.intersec)
    
    def __str__(self): #Imprimir el estado de cada nodo por pantalla
        return "Este es el estado " + str(self.intersec)

# %%
class Gproblema:
    def __init__(self, djson):
        #Apertura de json
        with open(djson, 'r') as archivo:
            self.datos = json.load(archivo)
        if self.datos is None: 
            raise ValueError("Error cargando el JSON")

        #Generación de estadísticas
        self.estadisticas = {
            "nodos_generados": 0,
            "expandidos": 0,
            "coste": 0,
            "profundidad": 0
        }

    #Es más rápido así porque cada vez que quisieramos buscar en el json tendríamos que leer todo lo anterior hasta encontrar
    #la intersección buscada. Así, lo que conseguimos es que al ser clave el identificador, es casi instantánea la búsqueda
    def Crear_Estructura(self):
        self.interseciones = {}
        self.vmax = 0
        self.candidatos = {}
        #Generación de diccionario de intersecciones
        #intersections en el json es un vector de diccionarios que contienen un id, la latitud y la longitud
        for interseccion in self.datos["intersections"]: #interseccion es cada uno de los diccionarios
            #metemos en el diccionario de intersecciones, donde la clave es el identificador, una tupla con la longitud y latitud
            self.interseciones[interseccion["identifier"]] = (interseccion["latitude"], interseccion["longitude"])
        self.tpop = 0;
        
        #Cambios
        indice = 0  # Contador
        self.iDCandidates = {}
        for a in self.datos["candidates"]:    
            self.candidatos[a[0]] = a[1]
            self.tpop = self.tpop + a[1]
            self.iDCandidates[indice] = a[0]  # Usamos el contador como clave
            indice += 1

        self.segmentos = {}
        #Generación de diccionario de segmentos que guardan los nodos destino
        #Cada posible origen se mira una única vez, por que en segmentos se repite muchas veces.
        for segmento in self.datos["segments"]:
                #Cambiamos priority queue por una lista y ordenarla cuando terminemos 
            if(segmento["origin"] not in self.segmentos):
                self.segmentos[segmento["origin"]] = [(segmento["destination"], segmento["distance"], segmento["speed"])]
            else: 
                self.segmentos[segmento["origin"]].append((segmento["destination"], segmento["distance"], segmento["speed"]))
            if segmento["speed"] > self.vmax:
                self.vmax = segmento["speed"]
        for i in self.segmentos:
            self.segmentos[i].sort()
            #IMPLEMENTAR: ORDENAR LAS LISTAS
        #Generación de estado inicial y final
        #Cambio, quitamos el estado inicial y final de problema
        #longi = 0
        #lat = 0
        #lat, longi = self.interseciones[self.datos["initial"]]
        #self.estadoini = Estado(self.datos["initial"], lat, longi)
        #lat, longi = self.interseciones[self.datos["final"]]
        #self.estadofin = Estado(self.datos["final"], lat, longi)
        #Cambios
    def setIniFin(self, inicial, final):
        lat, longi = self.interseciones[inicial]
        self.estadoini = Estado(inicial, lat, longi)
        lat, longi = self.interseciones[final]
        self.estadofin = Estado(final, lat, longi)

# %%
class Accion:
    def __init__(self, idOg, idDest, speed, distancia):
        self.idOg = idOg
        self.idDest = idDest
        self.speed = speed
        self.distancia = distancia
        self.tiempo = self.distancia / self.speed

# %%
class Nodo:
    def __init__(self, estado, padre, accion):
        self.estado = estado
        self.padre = padre
        self.accion = accion
        if padre:
            self.profundidad = padre.profundidad + 1
            self.costoG = padre.costoG + (accion.distancia/((accion.speed*1000)/3600))
        else:
            self.profundidad = 0
            self.costoG = 0 #Coste de la accion
            
    
    #Utilización de Manhattan para la heurística
    def heuristica(self,EstadoDestino, velMax):
        return  (abs(self.estado.latitud - EstadoDestino.latitud) + abs(self.estado.longitud - EstadoDestino.longitud))/((velMax*1000)/3600)
        

    def caminos_sol (self):
        camino = []
        nodo_actual = self 
        tiempoTotal = 0
        distanciaTotal = 0
        while nodo_actual:
            camino.append(nodo_actual.estado.intersec)
            distanciaTotal += nodo_actual.accion.distancia if nodo_actual.accion else 0
            tiempoTotal += (nodo_actual.accion.distancia/(nodo_actual.accion.speed*1000)) if nodo_actual.accion else 0
            nodo_actual = nodo_actual.padre
        camino.reverse() #Para que el camino aparezca en orden
        return camino, f" Se recorrio {distanciaTotal} metros en {tiempoTotal*60} minutos" # se multiplica por 60 para pasar de horas a minutos
    
    def __lt__(self, other):
        # Definimos que un Nodo es "menor que otro" si su costo es menor
        return self.costoG < other.costoG

# %%
class Busqueda(ABC): #ABC sirve para que la clase pueda tener métodos abstractos
    #Practica2: Añadimos inicial y final como parametros
    def __init__(self, problema,inicial,final):
        self.problema = problema
        problema.setIniFin(inicial,final)

    def Buscar(self):
        #iniciamos cronómetro para obtener el tiempo total de ejecución del programa
        inicio = time.time()
        #Creamos frontera, cerrados e insertamos el nodo inicial
        self.problema.Crear_Estructura()
        fronteraa = []
        cerrados = set() #Conjunto que no admite duplicados
        #Insertar es un método abstracto que se implementa en cada método de búsqueda, sirve para meter el nodo inicial
        self.Insertar(Nodo(self.problema.estadoini, None, None), fronteraa) 
        solucion = []
        #Comenzamos el bucle de búsqueda
        while True: #Es infinito por que ya existen condiciones que lo paran. Y no sabemos los nodos que hay que buscar
            if self.Vacia(fronteraa):
                print("No hay solucion")
                break
            nodo = self.BorrarPrimero(fronteraa)
            if self.TestObjetivo(nodo):
                solucion = nodo.caminos_sol()
                break
            if nodo.estado not in cerrados:
                cerrados.add(nodo.estado)
                self.InsertarTodo(self.Expandir(nodo),fronteraa)
        #Finalizamos cronómetro
        fin = time.time()

        #Creacioón de txt con la información
        logging.basicConfig(filename="Resultadotxt.txt", level=logging.INFO)
        logging.info("Problema:" + str(self.problema.datos["address"]))
        logging.info("Nodos Generados: " + str(self.problema.estadisticas["nodos_generados"]))
        logging.info("Nodos Expandidos: " + str(self.problema.estadisticas["expandidos"]))
        logging.info("Tiempo de ejecucion: " + str(fin - inicio))
        logging.info("Longitud de la solución: " + str(nodo.profundidad))
        logging.info("Coste de la solución: " + str(nodo.costoG))
        logging.info("Solución: " + str(solucion))
        logging.info("\n")
        logging.info("-----------------------------------------------------------")
        logging.info("\n")

        #Imprimimos la información
        print("Resultados también descargados en un archivo txt llamado Resultadotxt.txt")
        print("Problema:" + str(self.problema.datos["address"]))
        print("Nodos Generados: " + str(self.problema.estadisticas["nodos_generados"]))
        print("Nodos Expandidos: " + str(self.problema.estadisticas["expandidos"]))
        print("Tiempo de ejecucion: " + str(fin - inicio))
        print("Longitud de la solución: " + str(nodo.profundidad))
        print("Coste de la solución: " + str(nodo.costoG))
        print("Solución: " + str(solucion))
        return nodo.costoG

    #Comprobamos si es el estado final
    def TestObjetivo(self,nodo): #Porque nodo le vamos a hacer el mismo tratamiento dando igual el tipo de algoritmo
        if nodo.estado == self.problema.estadofin:
            return True
        return False
    
    def Solucion(self,nodo):
        nodo.caminossol()
    
    #Sacamos los hijos del nodo que pasamos por parámetro
    def Expandir(self,nodo):
        self.problema.estadisticas["expandidos"] += 1

        if nodo.estado.intersec in self.problema.segmentos:
            destinos = self.problema.segmentos[nodo.estado.intersec]
        else:
            print(f"Clave no encontrada: {nodo.estado.intersec}")
            return []  # No expandimos este nodo #Devuelve una priority queue que esta ordenada con todos los destinos
        nodosl = []
        nodoid = 0
        nodod = 0
        nodos = 0
        lat = 0
        longi = 0
        for destino in destinos:
            (nodoid, nodod, nodos) = destino #Sacamos el que tiene la prioridad, y devuelve la tupla de distancia y speed
            lat,longi = self.problema.interseciones[nodoid]
            #añadimos un nodo, con su padre y su accion
            nodosl.append(Nodo(Estado(nodoid,lat,longi), nodo,Accion(nodo.estado.intersec,nodoid,nodos,nodod)))
        return nodosl

            

    #En las búsquedas no informadas siempre vamos a sacar el primero de una lista 
    #En búsqueda informada siempre vamos a buscar por una heurística y para eso utilizamos priority queue        
    #Función que insertara en frontera el nodo inicial
    @abstractmethod
    def Insertar(self, nodo, frontera):
        pass

    #Función que comprobará si es vacía
    @abstractmethod
    def Vacia(self, frontera):
        pass

    #Función que borrará el primer nodo de la frontera
    @abstractmethod
    def BorrarPrimero(self, frontera):
        pass
    
    #Función que inserta una lista de nodos
    @abstractmethod
    def InsertarTodo(self, nodos,frontera):
        pass

# %%
class AEstrella (Busqueda):
    def Insertar(self, nodo, frontera):
        self.problema.estadisticas["nodos_generados"] +=1
        h = nodo.heuristica(self.problema.estadofin,self.problema.vmax)
        heapq.heappush(frontera,(nodo.costoG + h, nodo))
        
    def Vacia(self, frontera):
        if not frontera:
            return True
        return False
        
    def BorrarPrimero(self, frontera):
        p, n = heapq.heappop(frontera)
        return n
    
    def InsertarTodo(self, nodos,frontera):
        for nodo in nodos:
            self.problema.estadisticas["nodos_generados"] +=1
            heapq.heappush(frontera, (nodo.costoG + nodo.heuristica(self.problema.estadofin,self.problema.vmax), nodo))

# %%
class BusquedaMA(ABC):
    def __init__(self,djson):
        self.problema=Gproblema(djson)
        self.problema.Crear_Estructura()
        self.psolucion=[]
        self.calculados= {}

    def EsSolucion(self, lpsol):
        sumat = 0
        for candidato in self.problema.candidatos:
            min_tiempo = float('inf')
            for psol in lpsol:
                par = (candidato, psol)
                if par in self.calculados:
                    tiempo = self.calculados[par]
                else:
                    buscador = AEstrella(self.problema, candidato, psol)
                    tiempo = buscador.Buscar()
                    self.calculados[par] = tiempo
                if tiempo < min_tiempo:
                    min_tiempo = tiempo
            # Para el candidato, sumas su peso por el tiempo mínimo a una estación
            sumat += self.problema.candidatos[candidato] * min_tiempo
        sol = sumat / self.problema.tpop
        return sol

# %% [markdown]
# ## Búsqueda aleatoria

# %%
class BusquedaAleatoria(BusquedaMA):

    def Bus(self,sem,n):
        #iDCandidates
        inicio = time.time()
        random.seed(sem)

        long = len(self.problema.datos["candidates"])
        clavesAleatorias =  random.sample(range(long), self.problema.datos["number_stations"])
        clavesdic = {}
        for i in clavesAleatorias:
            clavesdic[i] = 0
        vIds = [0,""] * long
        sIds = []
        for i in range(long):
            if i in clavesdic:
                vIds[i] = [1,self.problema.iDCandidates[i]]
                sIds.append(self.problema.iDCandidates[i])
                continue
            vIds[i] = [0,self.problema.iDCandidates[i]]
        valor = self.EsSolucion(sIds)

        for i in range(n):
            vecinos = []
            mvecino = []
            mvalorvec = 3600 * 6
            vecsIds = sIds
            mvecsIds = []
            for i in range(long):
                for i in range(long):
                    for j in range(long):
                        vecino = vIds
                        if(i==j or vecino[i][0] == vecino[j][0]):
                            continue
                        primer = vecino[i][0]
                        vecino[i][0] = vecino[j][0]
                        vecino[j][0] = primer
                        for k in range(len(vecsIds)):
                            if(vecsIds[k]==vecino[i][1] and vecino[i][0] == 0):
                                vecsIds.pop(k)
                                vecsIds.append(vecino[j][1])
                                break
                            elif(vecsIds[k]==vecino[j][1] and vecino[j][0] == 0):
                                vecsIds.pop(k)
                                vecsIds.append(vecino[i][1])
                                break
                        valorvec = self.EsSolucion(vecsIds)
                        if(valorvec<mvalorvec):
                            mvalorvec = valorvec
                            mvecino = vecino
                            mvecsIds = vecsIds
            if(valor>mvalorvec):
                valor = mvalorvec
                vIds = mvecino
                sIds = mvecsIds
            else:
                clavesAleatorias =  random.sample(range(long), self.problema.datos["number_stations"])
                clavesdic = {}
                for i in clavesAleatorias:
                    clavesdic[i] = 0
                vIds = []
                sIds = []
                for i in range(long):
                    if i in clavesdic:
                        vIds[i] = [1,self.problema.iDCandidates[i]]
                        sIds.append(self.problema.iDCandidates[i])
                        continue
                    vIds[i] = [0,self.problema.iDCandidates[i]]
                valor = self.EsSolucion(sIds)
        
        fin = time.time()
        print(f"Solucion más optima encontrada {sIds}" )
        print(f"Fitness {valor}" )
        print(f"Número de iteraciones{n}")
        print(f"Tiempo de ejecución {(fin-inicio)//60} minutos {(fin-inicio)%60} segundos")




#tengo que coger de essolucion el valor optimo

# %% [markdown]
#  ProcedimientoAlgoritmoGenético
#  1.-t=0
#  2.- inicializarP(t)
#  3.-evaluarP(t)
#  4.-Mientras(nosecumplalacondicióndeparada)hacer
#  4.1.-t=t+1
#  4.2.-seleccionarP’(t)desdeP(t-1)
#  4.3.-recombinarP’(t)
#  4.4.-mutaciónP’(t)
#  4.5.-evaluarP’(t)
#  4.6.-P(t)=combinar(P’(t),P(t-1))

# %% [markdown]
# ## Algoritmo Genético

# %%
class AlgoritmoGenetico(BusquedaMA):
    def BusA(self,sem):
        random.seed(sem)

        t = 0
        #Generar población inicial
        Pt = self.InicioPoblacion(sem)
        #Calcular la evaluacion de cada individuo
        evaluados = self.EvaluarP(Pt)
        aptitudes = evaluados.copy()  # Guardamos las aptitudes para combinarlas más tarde
        while not t >= 500 : 
            t += 1
            # Seleccionar P'(t) desde P(t-1): Selección de padres
            Pprima = self.Selec(Pt, evaluados)
            # Recombinación P'(t): Cruzar los padres seleccionados
            Pprima = self.Recombinar(Pprima)
            #  Mutación P'(t): Aplicar mutaciones aleatorias
            Pprima = self.Mutar(Pprima)
            # 4.5.- Evaluar P'(t)
            evaluados_prima = self.EvaluarP(Pprima)
            # 4.6.- P(t) = combinar(P'(t), P(t-1))
            Pt, aptitudes = self.CombinarP(Pt, aptitudes, Pprima, evaluados_prima)

        #devolucion de la mejor solución encontrada
        mejorSol = self.ElMejor(Pt, aptitudes)
        return mejorSol
    
    def InicioPoblacion(self, sem):
        random.seed(sem)
        poblacion = []
        
        # Extraer solo el primer valor de cada subvector en "candidates"
        candidatos = [c[0] for c in self.problema.datos["candidates"]]
        nCandidatos = len(candidatos)  # Cantidad de candidatos
        
        for _ in range(nCandidatos):  # Tamaño de la población igual al número de candidatos
            # Elegir aleatoriamente los valores de los primeros elementos
            individuo = random.sample(candidatos, self.problema.datos["number_stations"])
            poblacion.append(individuo)
    
        return poblacion

    
    def EvaluarP (self, poblacion):
        return [self.EsSolucion(individuo) for individuo in poblacion]
    

    #Selección proporcional al fitness
    def Selec(self, poblacion, evaluados):
        losEvaluados = sum(evaluados)
        if losEvaluados == 0:
            print("Advertencia: Todas las evaluaciones son cero. Selección aleatoria aplicada.")
            return random.choices(poblacion, k=len(poblacion))
        prob = [evaluado / losEvaluados for evaluado in evaluados]
        padres = random.choices(poblacion, weights=prob, k=len(poblacion))
        return padres

    

    def Recombinar(self, poblacion):
        nGeneracion = []
        for i in range(0, len(poblacion), 2):
            padre1 = poblacion[i]
            padre2 = poblacion[i + 1] if i + 1 < len(poblacion) else poblacion[0]

            # Elegir dos puntos de cruce aleatorios
            i, d = sorted(random.sample(range(len(padre1)), 2))
            
            # Inicializar los hijos con segmentos externos de los padres
            #Cogemos el primer segmento de la izquierda del padre 1
            #En el medio ponemos el trozo de en medio del padre dos,
            #Se suma 1 para que se coja i:d , porque si no se cogeria de i a d-1
            #y por último se añade el resto del padre 1 y se le suma 1 para que llegue al final

                #Cruce básico
            hijo1 = padre1[:i] + padre2[i:d+1] + padre1[d+1:] #Con los dos puntos se consigue que pare en el punto de corte d
            hijo2 = padre2[:i] + padre1[i:d+1] + padre2[d+1:]
            
            nGeneracion.extend([hijo1, hijo2])
        return nGeneracion

    
    def Mutar(self, poblacion):
        for individuo in poblacion: #El individuo es una solucion candidata representada como una lista de genes
            if random.random() < 0.05: #Genera entre 0 y 1, si es menor a 0.2 muta, es decir, el 20% de la poblacion muta
                idx1, idx2 = random.sample(range(len(individuo)), 2) #Coge de manera aleatoria dos genes y los muta
                individuo[idx1], individuo[idx2] = individuo[idx2], individuo[idx1] #intercambiamos índices
        return poblacion
    

    
    def CombinarP(self, Pt, evaluados, Pprima, evPrima):
        combinados = list(zip(Pt + Pprima, evaluados + evPrima))
        combinados.sort(key=lambda x: x[1], reverse=True)
        nueva_poblacion = [ind for ind, _ in combinados[:len(Pt)]]
        nEvaluacion = [eval for _, eval in combinados[:len(Pt)]]
        return nueva_poblacion, nEvaluacion

    def ElMejor(self, poblacion, evaluados):
        max_evaluacion = max(evaluados)
        mejor_individuo = poblacion[evaluados.index(max_evaluacion)]
        return mejor_individuo

# %% [markdown]
# # Algoritmos de no continua

# %% [markdown]
# ### Hill-Climbing

# %%
class hill_climbing(BusquedaMA):

    def Bus(self, sem, it):
        """
        Método de búsqueda por Hill Climbing.
        param sem: Semilla para la generación aleatoria.
        param it: Número de iteraciones a realizar.
        return: Tupla con la mejor solución encontrada y su valor.
        """
        random.seed(sem)

        # Generar solución inicial aleatoria
        sol = self.Gen_sol_random()
        #comprobar si es solución
        actual = self.EsSolucion(sol)

        for _ in range(it):
            #generar vecinos
            vecinos = self.gen_vecinos(sol)
            
            #elegimos al mejor vecino
            mejor_vecino = None
            mejor_valor = actual

            for vecino in vecinos:
                v = self.EsSolucion(vecino)
                #si el vecino es mejor que la solución actual
                if v < mejor_valor:
                    mejor_valor = v
                    mejor_vecino = vecino
            
            #si no hay mejor vecino, salimos
            if mejor_vecino is None:
                break
            
            #si hay mejor vecino, lo actualizamos
            sol = mejor_vecino
            actual = mejor_valor

        return sol, actual


            

    def Gen_sol_random(self):
        """
        Método para generar una solución aleatoria.
        return: Lista de identificadores de intersecciones representando una solución aleatoria.
        """
        candidatos =[ c[0] for c in self.problema.datos["candidates"]] #Extraemos los identificadores de las intersecciones candidatas
        return random.sample(candidatos, self.problema.datos["number_stations"]) #devolvemos una lista de identificadores de intersecciones aleatorios, con el número de estaciones 

    def gen_vecinos(self, sol):
        """
        Método para generar vecinos de una solución dada.
        param sol: Lista de identificadores de intersecciones representando una solución.
        return: Lista de vecinos generados a partir de la solución dada.
        """
        vecinos = []
        for i in range(len(sol)):
            for j in range(i + 1, len(sol)): # para evitar repetir combinaciones
                # Intercambiar dos intersecciones para generar un vecino
                vecino = sol[:] #hacemos una copia de la solución actual
                vecino[i], vecino[j] = vecino[j], vecino[i] #cambiamos los valores de las posiciones i y j para generar un vecino
                
                vecinos.append(vecino) #añadimos el vecino a la lista de vecinos
        return vecinos

# %% [markdown]
# # MAIN
# llamadas algoritmo

# %%
BusquedaAL = BusquedaAleatoria(r"C:\Users\ramon\Desktop\Archivos uni\4 año\Inteligentes\Practica2\calle_agustina_aroca_albacete_250_0_candidates_75_ns_7.json")

BusquedaAL.Bus(69,10)

# BusquedaAL = AlgoritmoGenetico(r"C:\Users\Ana Barberá\Desktop\Práctica 2 Algoritmos metaheurísicos-20241215\sample-problems-lab2\medium\calle_agustina_aroca_albacete_500_1_candidates_89_ns_22.json")
# BusquedaAL.BusA(69)

# BusquedaMA = hill_climbing(r"C:\Users\Ana Barberá\Desktop\Práctica 2 Algoritmos metaheurísicos-20241215\sample-problems-lab2\medium\calle_agustina_aroca_albacete_500_1_candidates_89_ns_22.json")
# BusquedaMA.Bus(69, 1000)
# Out:
# Clave no encontrada: 1557262702
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 32
# Nodos Expandidos: 23
# Tiempo de ejecucion: 0.0010008811950683594
# Longitud de la solución: 11
# Coste de la solución: 57.96935999999999
# Solución: ([1572435237, 1572435249, 1574598070, 1572435255, 1554807113, 1526105986, 618009048, 1530209368, 1526105983, 1530209339, 335720312, 335607957], ' Se recorrio 483.078 metros en 0.9661560000000001 minutos')
# Clave no encontrada: 1557262702
# Clave no encontrada: 1835353347
# Clave no encontrada: 1560897811
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 110
# Nodos Expandidos: 74
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 19
# Coste de la solución: 91.24780000000001
# Solución: ([1572435237, 1572435249, 1574598070, 1572435255, 1554807113, 1526105986, 618009048, 1530209368, 1526105983, 1530209339, 335720312, 335607957, 335607958, 335896858, 335896877, 335720310, 1560897796, 1554807105, 1530209348, 1528181116], ' Se recorrio 767.2849999999999 metros en 1.5207966666666666 minutos')
# Clave no encontrada: 1557262702
# Clave no encontrada: 1835353347
# Clave no encontrada: 1560897811
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 201
# Nodos Expandidos: 133
# Tiempo de ejecucion: 0.0010004043579101562
# Longitud de la solución: 22
# Coste de la solución: 108.38536000000002
# Solución: ([1572435237, 1572435249, 1574598070, 1572435255, 1554807113, 1526105986, 618009048, 1530209368, 1526105983, 1530209339, 335720312, 335607957, 335607958, 335896858, 335896877, 335720310, 1560897796, 1554807105, 1530209348, 1528181116, 1528181128, 1528181133, 1528181134], ' Se recorrio 910.098 metros en 1.8064226666666667 minutos')
# Clave no encontrada: 1557262702
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 238
# Nodos Expandidos: 159
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 13
# Coste de la solución: 59.77295999999998
# Solución: ([1572435237, 1572435249, 1574598070, 1572435255, 1554807113, 1526105986, 618009048, 1530209368, 550376433, 1574608089, 1530897496, 1530897950, 550376452, 1530897624], ' Se recorrio 498.10800000000006 metros en 0.996216 minutos')
# Clave no encontrada: 1557262702
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 252
# Nodos Expandidos: 168
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 4
# Coste de la solución: 27.991079999999997
# Solución: ([1572435237, 1572435249, 1574598070, 1572435255, 1572435245], ' Se recorrio 233.25900000000001 metros en 0.46651800000000004 minutos')
# Clave no encontrada: 1557262702
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 295
# Nodos Expandidos: 197
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 12
# Coste de la solución: 62.14211999999999
# Solución: ([1572435237, 1572435249, 1574598070, 1572435255, 1554807113, 1526105986, 618009048, 1530209368, 1526105983, 1530209339, 335720312, 335607957, 1530209382], ' Se recorrio 529.442 metros en 1.0357020000000001 minutos')
# Clave no encontrada: 1557262702
# Clave no encontrada: 1835353347
# Clave no encontrada: 1560897811
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 371
# Nodos Expandidos: 246
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 15
# Coste de la solución: 87.63587999999999
# Solución: ([1572435237, 1572435249, 1574598070, 1572435255, 1554807113, 1526105986, 618009048, 1530209368, 550376433, 1574608089, 1530897496, 550376458, 1530897844, 1527972839, 1528822986, 1528822987], ' Se recorrio 730.299 metros en 1.460598 minutos')
# Clave no encontrada: 1557262702
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 445
# Nodos Expandidos: 295
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 14
# Coste de la solución: 74.28732
# Solución: ([1527972843, 1528822986, 1527972839, 1530897844, 550376458, 550376452, 1530897624, 550376456, 1530897682, 618009048, 1530209368, 1526105983, 1530209339, 335720312, 335607957], ' Se recorrio 619.061 metros en 1.238122 minutos')
# Clave no encontrada: 1557262702
# Clave no encontrada: 1835353347
# Clave no encontrada: 1528181129
# Clave no encontrada: 1560897811
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 541
# Nodos Expandidos: 360
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 11
# Coste de la solución: 89.58035999999998
# Solución: ([1527972843, 1528822986, 1528822987, 1554813465, 335720315, 1554813429, 335720305, 1528181137, 1528181133, 1528181113, 1970003852, 1528181116], ' Se recorrio 746.5029999999999 metros en 1.493006 minutos')
# Clave no encontrada: 1557262702
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 606
# Nodos Expandidos: 401
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 9
# Coste de la solución: 69.48599999999999
# Solución: ([1527972843, 1528822986, 1528822987, 1554813465, 335720315, 1554813429, 335720305, 1528181137, 1528181133, 1528181134], ' Se recorrio 579.0500000000001 metros en 1.1581000000000001 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 620
# Nodos Expandidos: 409
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 6
# Coste de la solución: 33.07752
# Solución: ([1527972843, 1528822986, 1527972839, 1530897844, 550376458, 550376452, 1530897624], ' Se recorrio 275.646 metros en 0.551292 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 652
# Nodos Expandidos: 427
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 9
# Coste de la solución: 48.28944
# Solución: ([1527972843, 1528822986, 1527972839, 1530897844, 550376458, 550376452, 1530897624, 1526106002, 1526105938, 1572435245], ' Se recorrio 402.4119999999999 metros en 0.804824 minutos')
# Clave no encontrada: 1557262702
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 735
# Nodos Expandidos: 481
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 15
# Coste de la solución: 78.46007999999999
# Solución: ([1527972843, 1528822986, 1527972839, 1530897844, 550376458, 550376452, 1530897624, 550376456, 1530897682, 618009048, 1530209368, 1526105983, 1530209339, 335720312, 335607957, 1530209382], ' Se recorrio 665.4250000000001 metros en 1.3076679999999998 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 742
# Nodos Expandidos: 484
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 2
# Coste de la solución: 19.2168
# Solución: ([1527972843, 1528822986, 1528822987], ' Se recorrio 160.14 metros en 0.32028 minutos')
# Clave no encontrada: 1557262702
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 817
# Nodos Expandidos: 534
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 15
# Coste de la solución: 80.87664
# Solución: ([1554813467, 1527972843, 1528822986, 1527972839, 1530897844, 550376458, 550376452, 1530897624, 550376456, 1530897682, 618009048, 1530209368, 1526105983, 1530209339, 335720312, 335607957], ' Se recorrio 673.972 metros en 1.3479439999999998 minutos')
# Clave no encontrada: 1557262702
# Clave no encontrada: 1835353347
# Clave no encontrada: 1528181129
# Clave no encontrada: 1560897811
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 914
# Nodos Expandidos: 600
# Tiempo de ejecucion: 0.0010008811950683594
# Longitud de la solución: 12
# Coste de la solución: 96.16967999999999
# Solución: ([1554813467, 1527972843, 1528822986, 1528822987, 1554813465, 335720315, 1554813429, 335720305, 1528181137, 1528181133, 1528181113, 1970003852, 1528181116], ' Se recorrio 801.414 metros en 1.602828 minutos')
# Clave no encontrada: 1557262702
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 980
# Nodos Expandidos: 642
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 10
# Coste de la solución: 76.07531999999999
# Solución: ([1554813467, 1527972843, 1528822986, 1528822987, 1554813465, 335720315, 1554813429, 335720305, 1528181137, 1528181133, 1528181134], ' Se recorrio 633.961 metros en 1.267922 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 995
# Nodos Expandidos: 651
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 7
# Coste de la solución: 39.66684
# Solución: ([1554813467, 1527972843, 1528822986, 1527972839, 1530897844, 550376458, 550376452, 1530897624], ' Se recorrio 330.557 metros en 0.661114 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 1028
# Nodos Expandidos: 670
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 10
# Coste de la solución: 54.87876
# Solución: ([1554813467, 1527972843, 1528822986, 1527972839, 1530897844, 550376458, 550376452, 1530897624, 1526106002, 1526105938, 1572435245], ' Se recorrio 457.3229999999999 metros en 0.914646 minutos')
# Clave no encontrada: 1557262702
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 1112
# Nodos Expandidos: 725
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 16
# Coste de la solución: 85.04939999999999
# Solución: ([1554813467, 1527972843, 1528822986, 1527972839, 1530897844, 550376458, 550376452, 1530897624, 550376456, 1530897682, 618009048, 1530209368, 1526105983, 1530209339, 335720312, 335607957, 1530209382], ' Se recorrio 720.336 metros en 1.41749 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 1120
# Nodos Expandidos: 729
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 3
# Coste de la solución: 25.80612
# Solución: ([1554813467, 1527972843, 1528822986, 1528822987], ' Se recorrio 215.051 metros en 0.43010200000000004 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 1126
# Nodos Expandidos: 733
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 3
# Coste de la solución: 8.875559999999998
# Solución: ([550378434, 1530209339, 335720312, 335607957], ' Se recorrio 73.963 metros en 0.14792599999999997 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 1178
# Nodos Expandidos: 767
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 11
# Coste de la solución: 42.153999999999996
# Solución: ([550378434, 1530209339, 335720312, 335607957, 335607958, 335896858, 335896877, 335720310, 1560897796, 1554807105, 1530209348, 1528181116], ' Se recorrio 358.16999999999996 metros en 0.7025666666666668 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Clave no encontrada: 1557262702
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 1258
# Nodos Expandidos: 819
# Tiempo de ejecucion: 0.0010008811950683594
# Longitud de la solución: 14
# Coste de la solución: 59.29155999999999
# Solución: ([550378434, 1530209339, 335720312, 335607957, 335607958, 335896858, 335896877, 335720310, 1560897796, 1554807105, 1530209348, 1528181116, 1528181128, 1528181133, 1528181134], ' Se recorrio 500.983 metros en 0.9881926666666668 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 1292
# Nodos Expandidos: 842
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 7
# Coste de la solución: 31.194959999999995
# Solución: ([550378434, 1991970566, 550376433, 1574608089, 1530897496, 1530897950, 550376452, 1530897624], ' Se recorrio 259.958 metros en 0.5199159999999999 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 1346
# Nodos Expandidos: 877
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 10
# Coste de la solución: 46.40688
# Solución: ([550378434, 1991970566, 550376433, 1574608089, 1530897496, 1530897950, 550376452, 1530897624, 1526106002, 1526105938, 1572435245], ' Se recorrio 386.72399999999993 metros en 0.7734479999999999 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 1359
# Nodos Expandidos: 885
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 4
# Coste de la solución: 13.048319999999999
# Solución: ([550378434, 1530209339, 335720312, 335607957, 1530209382], ' Se recorrio 120.327 metros en 0.217472 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Clave no encontrada: 1557262702
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 1438
# Nodos Expandidos: 936
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 9
# Coste de la solución: 59.05788
# Solución: ([550378434, 1991970566, 550376433, 1574608089, 1530897496, 550376458, 1530897844, 1527972839, 1528822986, 1528822987], ' Se recorrio 492.149 metros en 0.9842980000000002 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 1439
# Nodos Expandidos: 936
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 0
# Coste de la solución: 0
# Solución: ([335607957], ' Se recorrio 0 metros en 0 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 1471
# Nodos Expandidos: 958
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 8
# Coste de la solución: 33.278439999999996
# Solución: ([335607957, 335607958, 335896858, 335896877, 335720310, 1560897796, 1554807105, 1530209348, 1528181116], ' Se recorrio 284.207 metros en 0.5546406666666667 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 1527
# Nodos Expandidos: 994
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 11
# Coste de la solución: 50.41599999999999
# Solución: ([335607957, 335607958, 335896858, 335896877, 335720310, 1560897796, 1554807105, 1530209348, 1528181116, 1528181128, 1528181133, 1528181134], ' Se recorrio 427.02000000000004 metros en 0.8402666666666667 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 1574
# Nodos Expandidos: 1025
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 13
# Coste de la solución: 46.57371999999999
# Solución: ([335607957, 335607958, 335896858, 335896877, 335720310, 1560897796, 550378434, 1991970566, 550376433, 1574608089, 1530897496, 1530897950, 550376452, 1530897624], ' Se recorrio 395.0010000000001 metros en 0.7762286666666668 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 1642
# Nodos Expandidos: 1070
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 16
# Coste de la solución: 61.78563999999999
# Solución: ([335607957, 335607958, 335896858, 335896877, 335720310, 1560897796, 550378434, 1991970566, 550376433, 1574608089, 1530897496, 1530897950, 550376452, 1530897624, 1526106002, 1526105938, 1572435245], ' Se recorrio 521.7669999999999 metros en 1.0297606666666665 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 1649
# Nodos Expandidos: 1073
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 1
# Coste de la solución: 4.17276
# Solución: ([335607957, 1530209382], ' Se recorrio 46.364000000000004 metros en 0.06954600000000001 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Clave no encontrada: 1528181129
# Clave no encontrada: 1557262702
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 1736
# Nodos Expandidos: 1132
# Tiempo de ejecucion: 0.0009982585906982422
# Longitud de la solución: 15
# Coste de la solución: 74.43664
# Solución: ([335607957, 335607958, 335896858, 335896877, 335720310, 1560897796, 550378434, 1991970566, 550376433, 1574608089, 1530897496, 550376458, 1530897844, 1527972839, 1528822986, 1528822987], ' Se recorrio 627.192 metros en 1.2406106666666668 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 1740
# Nodos Expandidos: 1134
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 2
# Coste de la solución: 3.0171599999999996
# Solución: ([335720310, 335720312, 335607957], ' Se recorrio 25.143 metros en 0.050286000000000004 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 1772
# Nodos Expandidos: 1156
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 4
# Coste de la solución: 25.563359999999996
# Solución: ([335720310, 1560897796, 1554807105, 1530209348, 1528181116], ' Se recorrio 213.028 metros en 0.426056 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 1828
# Nodos Expandidos: 1192
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 7
# Coste de la solución: 42.70091999999999
# Solución: ([335720310, 1560897796, 1554807105, 1530209348, 1528181116, 1528181128, 1528181133, 1528181134], ' Se recorrio 355.841 metros en 0.7116819999999999 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 1875
# Nodos Expandidos: 1223
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 9
# Coste de la solución: 38.85863999999999
# Solución: ([335720310, 1560897796, 550378434, 1991970566, 550376433, 1574608089, 1530897496, 1530897950, 550376452, 1530897624], ' Se recorrio 323.82200000000006 metros en 0.647644 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 1943
# Nodos Expandidos: 1268
# Tiempo de ejecucion: 0.0010004043579101562
# Longitud de la solución: 12
# Coste de la solución: 54.070559999999986
# Solución: ([335720310, 1560897796, 550378434, 1991970566, 550376433, 1574608089, 1530897496, 1530897950, 550376452, 1530897624, 1526106002, 1526105938, 1572435245], ' Se recorrio 450.58799999999997 metros en 0.901176 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 1955
# Nodos Expandidos: 1274
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 3
# Coste de la solución: 7.18992
# Solución: ([335720310, 335720312, 335607957, 1530209382], ' Se recorrio 71.507 metros en 0.11983200000000001 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Clave no encontrada: 1528181129
# Clave no encontrada: 1557262702
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 2042
# Nodos Expandidos: 1333
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 11
# Coste de la solución: 66.72156
# Solución: ([335720310, 1560897796, 550378434, 1991970566, 550376433, 1574608089, 1530897496, 550376458, 1530897844, 1527972839, 1528822986, 1528822987], ' Se recorrio 556.013 metros en 1.1120260000000002 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 2108
# Nodos Expandidos: 1377
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 10
# Coste de la solución: 58.75872
# Solución: ([335720308, 1554813465, 335720315, 1554813429, 1574608082, 1560897869, 1991970573, 550378434, 1530209339, 335720312, 335607957], ' Se recorrio 489.65600000000006 metros en 0.9793119999999998 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 2180
# Nodos Expandidos: 1424
# Tiempo de ejecucion: 0.0005767345428466797
# Longitud de la solución: 9
# Coste de la solución: 60.861239999999995
# Solución: ([335720308, 1554813465, 335720315, 1554813429, 335720305, 1528181137, 1528181133, 1528181113, 1970003852, 1528181116], ' Se recorrio 507.177 metros en 1.014354 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 2210
# Nodos Expandidos: 1441
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 7
# Coste de la solución: 40.76687999999999
# Solución: ([335720308, 1554813465, 335720315, 1554813429, 335720305, 1528181137, 1528181133, 1528181134], ' Se recorrio 339.72400000000005 metros en 0.679448 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 2238
# Nodos Expandidos: 1457
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 7
# Coste de la solución: 40.1316
# Solución: ([335720308, 1554813465, 335720315, 1528822981, 1530897844, 550376458, 550376452, 1530897624], ' Se recorrio 334.43 metros en 0.66886 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 2295
# Nodos Expandidos: 1494
# Tiempo de ejecucion: 0.0011413097381591797
# Longitud de la solución: 10
# Coste de la solución: 55.34352
# Solución: ([335720308, 1554813465, 335720315, 1528822981, 1530897844, 550376458, 550376452, 1530897624, 1526106002, 1526105938, 1572435245], ' Se recorrio 461.19599999999997 metros en 0.922392 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 2372
# Nodos Expandidos: 1544
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 11
# Coste de la solución: 62.93147999999999
# Solución: ([335720308, 1554813465, 335720315, 1554813429, 1574608082, 1560897869, 1991970573, 550378434, 1530209339, 335720312, 335607957, 1530209382], ' Se recorrio 536.02 metros en 1.0488579999999998 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 2389
# Nodos Expandidos: 1554
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 4
# Coste de la solución: 35.142179999999996
# Solución: ([335720308, 1554813465, 335720315, 1528822981, 1528822987], ' Se recorrio 248.905 metros en 0.585703 minutos')
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 2415
# Nodos Expandidos: 1572
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 7
# Coste de la solución: 37.59983999999999
# Solución: ([1554807113, 1526105986, 618009048, 1530209368, 1526105983, 1530209339, 335720312, 335607957], ' Se recorrio 313.332 metros en 0.626664 minutos')
# Clave no encontrada: 1835353347
# Clave no encontrada: 1557262702
# Clave no encontrada: 1560897811
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 2493
# Nodos Expandidos: 1623
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 15
# Coste de la solución: 70.87827999999999
# Solución: ([1554807113, 1526105986, 618009048, 1530209368, 1526105983, 1530209339, 335720312, 335607957, 335607958, 335896858, 335896877, 335720310, 1560897796, 1554807105, 1530209348, 1528181116], ' Se recorrio 597.5389999999999 metros en 1.1813046666666667 minutos')
# Clave no encontrada: 1835353347
# Clave no encontrada: 1557262702
# Clave no encontrada: 1560897811
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 2584
# Nodos Expandidos: 1682
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 18
# Coste de la solución: 88.01584
# Solución: ([1554807113, 1526105986, 618009048, 1530209368, 1526105983, 1530209339, 335720312, 335607957, 335607958, 335896858, 335896877, 335720310, 1560897796, 1554807105, 1530209348, 1528181116, 1528181128, 1528181133, 1528181134], ' Se recorrio 740.352 metros en 1.4669306666666668 minutos')
# Clave no encontrada: 1835353347
# Clave no encontrada: 1557262702
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 2616
# Nodos Expandidos: 1705
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 9
# Coste de la solución: 39.40343999999999
# Solución: ([1554807113, 1526105986, 618009048, 1530209368, 550376433, 1574608089, 1530897496, 1530897950, 550376452, 1530897624], ' Se recorrio 328.362 metros en 0.656724 minutos')
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 2631
# Nodos Expandidos: 1715
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 4
# Coste de la solución: 29.899799999999995
# Solución: ([1554807113, 1526105986, 1526106002, 1526105938, 1572435245], ' Se recorrio 249.16500000000002 metros en 0.49833000000000005 minutos')
# Clave no encontrada: 1835353347
# Clave no encontrada: 1557262702
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 2669
# Nodos Expandidos: 1741
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 8
# Coste de la solución: 41.7726
# Solución: ([1554807113, 1526105986, 618009048, 1530209368, 1526105983, 1530209339, 335720312, 335607957, 1530209382], ' Se recorrio 359.696 metros en 0.69621 minutos')
# Clave no encontrada: 1835353347
# Clave no encontrada: 1557262702
# Clave no encontrada: 1560897811
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 2745
# Nodos Expandidos: 1790
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 11
# Coste de la solución: 67.26635999999999
# Solución: ([1554807113, 1526105986, 618009048, 1530209368, 550376433, 1574608089, 1530897496, 550376458, 1530897844, 1527972839, 1528822986, 1528822987], ' Se recorrio 560.553 metros en 1.1211060000000002 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 2815
# Nodos Expandidos: 1836
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 14
# Coste de la solución: 104.07647999999999
# Solución: ([1528181116, 1528181138, 335720304, 335720305, 335720308, 1554813465, 335720315, 1554813429, 1574608082, 1560897869, 1991970573, 550378434, 1530209339, 335720312, 335607957], ' Se recorrio 867.3040000000001 metros en 1.734608 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 2816
# Nodos Expandidos: 1836
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 0
# Coste de la solución: 0
# Solución: ([1528181116], ' Se recorrio 0 metros en 0 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 2826
# Nodos Expandidos: 1842
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 3
# Coste de la solución: 17.13756
# Solución: ([1528181116, 1528181128, 1528181133, 1528181134], ' Se recorrio 142.813 metros en 0.285626 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 2866
# Nodos Expandidos: 1868
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 11
# Coste de la solución: 85.44935999999997
# Solución: ([1528181116, 1528181138, 335720304, 335720305, 335720308, 1554813465, 335720315, 1528822981, 1530897844, 550376458, 550376452, 1530897624], ' Se recorrio 712.078 metros en 1.424156 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 2928
# Nodos Expandidos: 1908
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 14
# Coste de la solución: 100.66127999999996
# Solución: ([1528181116, 1528181138, 335720304, 335720305, 335720308, 1554813465, 335720315, 1528822981, 1530897844, 550376458, 550376452, 1530897624, 1526106002, 1526105938, 1572435245], ' Se recorrio 838.8439999999999 metros en 1.677688 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 3007
# Nodos Expandidos: 1959
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 15
# Coste de la solución: 108.24923999999999
# Solución: ([1528181116, 1528181138, 335720304, 335720305, 335720308, 1554813465, 335720315, 1554813429, 1574608082, 1560897869, 1991970573, 550378434, 1530209339, 335720312, 335607957, 1530209382], ' Se recorrio 913.668 metros en 1.8041539999999998 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 3038
# Nodos Expandidos: 1980
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 8
# Coste de la solución: 80.45993999999999
# Solución: ([1528181116, 1528181138, 335720304, 335720305, 335720308, 1554813465, 335720315, 1528822981, 1528822987], ' Se recorrio 626.553 metros en 1.340999 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 3110
# Nodos Expandidos: 2027
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 17
# Coste de la solución: 126.09983999999999
# Solución: ([1574608077, 1560900349, 1528181137, 1528181111, 1528181138, 335720304, 335720305, 335720308, 1554813465, 335720315, 1554813429, 1574608082, 1560897869, 1991970573, 550378434, 1530209339, 335720312, 335607957], ' Se recorrio 1050.832 metros en 2.101664 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 3126
# Nodos Expandidos: 2039
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 6
# Coste de la solución: 44.01935999999999
# Solución: ([1574608077, 1560900349, 1528181137, 1528181133, 1528181113, 1970003852, 1528181116], ' Se recorrio 366.828 metros en 0.7336560000000001 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 3135
# Nodos Expandidos: 2045
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 4
# Coste de la solución: 23.924999999999997
# Solución: ([1574608077, 1560900349, 1528181137, 1528181133, 1528181134], ' Se recorrio 199.375 metros en 0.39875 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 3177
# Nodos Expandidos: 2072
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 14
# Coste de la solución: 107.47271999999997
# Solución: ([1574608077, 1560900349, 1528181137, 1528181111, 1528181138, 335720304, 335720305, 335720308, 1554813465, 335720315, 1528822981, 1530897844, 550376458, 550376452, 1530897624], ' Se recorrio 895.606 metros en 1.791212 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 3241
# Nodos Expandidos: 2113
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 17
# Coste de la solución: 122.68463999999996
# Solución: ([1574608077, 1560900349, 1528181137, 1528181111, 1528181138, 335720304, 335720305, 335720308, 1554813465, 335720315, 1528822981, 1530897844, 550376458, 550376452, 1530897624, 1526106002, 1526105938, 1572435245], ' Se recorrio 1022.3719999999998 metros en 2.044744 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 3322
# Nodos Expandidos: 2165
# Tiempo de ejecucion: 0.0010075569152832031
# Longitud de la solución: 18
# Coste de la solución: 130.27259999999998
# Solución: ([1574608077, 1560900349, 1528181137, 1528181111, 1528181138, 335720304, 335720305, 335720308, 1554813465, 335720315, 1554813429, 1574608082, 1560897869, 1991970573, 550378434, 1530209339, 335720312, 335607957, 1530209382], ' Se recorrio 1097.1960000000001 metros en 2.1712100000000003 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 3355
# Nodos Expandidos: 2187
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 11
# Coste de la solución: 102.48329999999999
# Solución: ([1574608077, 1560900349, 1528181137, 1528181111, 1528181138, 335720304, 335720305, 335720308, 1554813465, 335720315, 1528822981, 1528822987], ' Se recorrio 810.0809999999999 metros en 1.7080550000000003 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 3357
# Nodos Expandidos: 2188
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 1
# Coste de la solución: 1.53528
# Solución: ([335720312, 335607957], ' Se recorrio 12.794 metros en 0.025588 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 3389
# Nodos Expandidos: 2210
# Tiempo de ejecucion: 0.0009987354278564453
# Longitud de la solución: 9
# Coste de la solución: 34.813719999999996
# Solución: ([335720312, 335607957, 335607958, 335896858, 335896877, 335720310, 1560897796, 1554807105, 1530209348, 1528181116], ' Se recorrio 297.001 metros en 0.5802286666666667 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 3445
# Nodos Expandidos: 2246
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 12
# Coste de la solución: 51.95127999999999
# Solución: ([335720312, 335607957, 335607958, 335896858, 335896877, 335720310, 1560897796, 1554807105, 1530209348, 1528181116, 1528181128, 1528181133, 1528181134], ' Se recorrio 439.814 metros en 0.8658546666666668 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 3492
# Nodos Expandidos: 2277
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 14
# Coste de la solución: 48.10899999999999
# Solución: ([335720312, 335607957, 335607958, 335896858, 335896877, 335720310, 1560897796, 550378434, 1991970566, 550376433, 1574608089, 1530897496, 1530897950, 550376452, 1530897624], ' Se recorrio 407.7950000000001 metros en 0.8018166666666667 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 3560
# Nodos Expandidos: 2322
# Tiempo de ejecucion: 0.0012543201446533203
# Longitud de la solución: 17
# Coste de la solución: 63.32091999999999
# Solución: ([335720312, 335607957, 335607958, 335896858, 335896877, 335720310, 1560897796, 550378434, 1991970566, 550376433, 1574608089, 1530897496, 1530897950, 550376452, 1530897624, 1526106002, 1526105938, 1572435245], ' Se recorrio 534.5609999999999 metros en 1.0553486666666667 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 3568
# Nodos Expandidos: 2326
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 2
# Coste de la solución: 5.7080400000000004
# Solución: ([335720312, 335607957, 1530209382], ' Se recorrio 59.158 metros en 0.09513400000000001 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Clave no encontrada: 1528181129
# Clave no encontrada: 1557262702
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 3655
# Nodos Expandidos: 2385
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 16
# Coste de la solución: 75.97192
# Solución: ([335720312, 335607957, 335607958, 335896858, 335896877, 335720310, 1560897796, 550378434, 1991970566, 550376433, 1574608089, 1530897496, 550376458, 1530897844, 1527972839, 1528822986, 1528822987], ' Se recorrio 639.986 metros en 1.2661986666666667 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 3661
# Nodos Expandidos: 2388
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 1
# Coste de la solución: 3.7541999999999995
# Solución: ([335896877, 335607957], ' Se recorrio 31.285 metros en 0.06257 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 3693
# Nodos Expandidos: 2410
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 5
# Coste de la solución: 27.518759999999993
# Solución: ([335896877, 335720310, 1560897796, 1554807105, 1530209348, 1528181116], ' Se recorrio 229.32299999999998 metros en 0.458646 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 3749
# Nodos Expandidos: 2446
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 8
# Coste de la solución: 44.65631999999999
# Solución: ([335896877, 335720310, 1560897796, 1554807105, 1530209348, 1528181116, 1528181128, 1528181133, 1528181134], ' Se recorrio 372.136 metros en 0.744272 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 3796
# Nodos Expandidos: 2477
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 10
# Coste de la solución: 40.81403999999999
# Solución: ([335896877, 335720310, 1560897796, 550378434, 1991970566, 550376433, 1574608089, 1530897496, 1530897950, 550376452, 1530897624], ' Se recorrio 340.1170000000001 metros en 0.680234 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 3864
# Nodos Expandidos: 2522
# Tiempo de ejecucion: 0.0005867481231689453
# Longitud de la solución: 13
# Coste de la solución: 56.02596
# Solución: ([335896877, 335720310, 1560897796, 550378434, 1991970566, 550376433, 1574608089, 1530897496, 1530897950, 550376452, 1530897624, 1526106002, 1526105938, 1572435245], ' Se recorrio 466.883 metros en 0.933766 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 3878
# Nodos Expandidos: 2529
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 2
# Coste de la solución: 7.926959999999999
# Solución: ([335896877, 335607957, 1530209382], ' Se recorrio 77.649 metros en 0.132116 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Clave no encontrada: 1528181129
# Clave no encontrada: 1557262702
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 3965
# Nodos Expandidos: 2588
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 12
# Coste de la solución: 68.67696
# Solución: ([335896877, 335720310, 1560897796, 550378434, 1991970566, 550376433, 1574608089, 1530897496, 550376458, 1530897844, 1527972839, 1528822986, 1528822987], ' Se recorrio 572.308 metros en 1.1446160000000003 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 4035
# Nodos Expandidos: 2634
# Tiempo de ejecucion: 0.001035928726196289
# Longitud de la solución: 18
# Coste de la solución: 137.97504
# Solución: ([1528181134, 1560900347, 1560900349, 1528181137, 1528181111, 1528181138, 335720304, 335720305, 335720308, 1554813465, 335720315, 1554813429, 1574608082, 1560897869, 1991970573, 550378434, 1530209339, 335720312, 335607957], ' Se recorrio 1149.7920000000001 metros en 2.2995840000000003 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 4049
# Nodos Expandidos: 2645
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 7
# Coste de la solución: 55.894559999999984
# Solución: ([1528181134, 1560900347, 1560900349, 1528181137, 1528181133, 1528181113, 1970003852, 1528181116], ' Se recorrio 465.78799999999995 metros en 0.931576 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 4050
# Nodos Expandidos: 2645
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 0
# Coste de la solución: 0
# Solución: ([1528181134], ' Se recorrio 0 metros en 0 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 4090
# Nodos Expandidos: 2671
# Tiempo de ejecucion: 0.0010352134704589844
# Longitud de la solución: 15
# Coste de la solución: 119.34791999999997
# Solución: ([1528181134, 1560900347, 1560900349, 1528181137, 1528181111, 1528181138, 335720304, 335720305, 335720308, 1554813465, 335720315, 1528822981, 1530897844, 550376458, 550376452, 1530897624], ' Se recorrio 994.566 metros en 1.989132 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 4152
# Nodos Expandidos: 2711
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 18
# Coste de la solución: 134.55983999999998
# Solución: ([1528181134, 1560900347, 1560900349, 1528181137, 1528181111, 1528181138, 335720304, 335720305, 335720308, 1554813465, 335720315, 1528822981, 1530897844, 550376458, 550376452, 1530897624, 1526106002, 1526105938, 1572435245], ' Se recorrio 1121.3319999999999 metros en 2.242664 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 4231
# Nodos Expandidos: 2762
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 19
# Coste de la solución: 142.14780000000002
# Solución: ([1528181134, 1560900347, 1560900349, 1528181137, 1528181111, 1528181138, 335720304, 335720305, 335720308, 1554813465, 335720315, 1554813429, 1574608082, 1560897869, 1991970573, 550378434, 1530209339, 335720312, 335607957, 1530209382], ' Se recorrio 1196.156 metros en 2.36913 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 4262
# Nodos Expandidos: 2783
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 12
# Coste de la solución: 114.35849999999999
# Solución: ([1528181134, 1560900347, 1560900349, 1528181137, 1528181111, 1528181138, 335720304, 335720305, 335720308, 1554813465, 335720315, 1528822981, 1528822987], ' Se recorrio 909.0409999999999 metros en 1.9059750000000002 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 4269
# Nodos Expandidos: 2787
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 2
# Coste de la solución: 4.1674
# Solución: ([335896858, 335896877, 335607957], ' Se recorrio 41.615 metros en 0.06945666666666667 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 4301
# Nodos Expandidos: 2809
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 6
# Coste de la solución: 27.931959999999997
# Solución: ([335896858, 335896877, 335720310, 1560897796, 1554807105, 1530209348, 1528181116], ' Se recorrio 239.653 metros en 0.46553266666666665 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 4357
# Nodos Expandidos: 2845
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 9
# Coste de la solución: 45.06951999999999
# Solución: ([335896858, 335896877, 335720310, 1560897796, 1554807105, 1530209348, 1528181116, 1528181128, 1528181133, 1528181134], ' Se recorrio 382.466 metros en 0.7511586666666668 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 4404
# Nodos Expandidos: 2876
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 11
# Coste de la solución: 41.22723999999999
# Solución: ([335896858, 335896877, 335720310, 1560897796, 550378434, 1991970566, 550376433, 1574608089, 1530897496, 1530897950, 550376452, 1530897624], ' Se recorrio 350.44700000000006 metros en 0.6871206666666667 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 4472
# Nodos Expandidos: 2921
# Tiempo de ejecucion: 0.0010902881622314453
# Longitud de la solución: 14
# Coste de la solución: 56.43915999999999
# Solución: ([335896858, 335896877, 335720310, 1560897796, 550378434, 1991970566, 550376433, 1574608089, 1530897496, 1530897950, 550376452, 1530897624, 1526106002, 1526105938, 1572435245], ' Se recorrio 477.21299999999997 metros en 0.9406526666666667 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 4487
# Nodos Expandidos: 2929
# Tiempo de ejecucion: 0.0
# ...
# Clave no encontrada: 1835353347
# Clave no encontrada: 1560897811
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 313437
# Nodos Expandidos: 205510
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 18
# Coste de la solución: 73.82452
# Solución: ([1530209382, 1526105983, 1530209339, 335720312, 335607957, 335607958, 335896858, 335896877, 335720310, 1560897796, 550378434, 1991970566, 550376433, 1574608089, 1530897496, 1530897950, 550376452, 1530897624, 550376456], ' Se recorrio 622.0910000000001 metros en 1.2304086666666667 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 313450
# Nodos Expandidos: 205517
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 6
# Coste de la solución: 11.24232
# Solución: ([1530897682, 1574608089, 1530897496, 1530897950, 550376452, 1530897624, 550376456], ' Se recorrio 93.68599999999999 metros en 0.18737199999999998 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 313463
# Nodos Expandidos: 205523
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 4
# Coste de la solución: 15.472560000000001
# Solución: ([1530897844, 550376458, 550376452, 1530897624, 550376456], ' Se recorrio 128.93800000000002 metros en 0.257876 minutos')
# Clave no encontrada: 1557262702
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 313508
# Nodos Expandidos: 205553
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 12
# Coste de la solución: 48.68675999999999
# Solución: ([1574598070, 1572435255, 1554807113, 1526105986, 618009048, 1530209368, 550376433, 1574608089, 1530897496, 1530897950, 550376452, 1530897624, 550376456], ' Se recorrio 405.723 metros en 0.8114459999999999 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 313533
# Nodos Expandidos: 205568
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 7
# Coste de la solución: 26.686559999999997
# Solución: ([1530209368, 550376433, 1574608089, 1530897496, 1530897950, 550376452, 1530897624, 550376456], ' Se recorrio 222.388 metros en 0.444776 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 313549
# Nodos Expandidos: 205577
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 5
# Coste de la solución: 23.070479999999996
# Solución: ([1527972839, 1530897844, 550376458, 550376452, 1530897624, 550376456], ' Se recorrio 192.25400000000002 metros en 0.384508 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 313591
# Nodos Expandidos: 205604
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 13
# Coste de la solución: 96.90671999999996
# Solución: ([1970003852, 1528181116, 1528181138, 335720304, 335720305, 335720308, 1554813465, 335720315, 1528822981, 1530897844, 550376458, 550376452, 1530897624, 550376456], ' Se recorrio 807.556 metros en 1.615112 minutos')
# Clave no encontrada: 1835353347
# No hay solucion
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 313592
# Nodos Expandidos: 205605
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 0
# Coste de la solución: 0
# Solución: []
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 313600
# Nodos Expandidos: 205609
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 3
# Coste de la solución: 7.82268
# Solución: ([550376458, 550376452, 1530897624, 550376456], ' Se recorrio 65.18900000000001 metros en 0.13037800000000002 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 313631
# Nodos Expandidos: 205627
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 8
# Coste de la solución: 52.580639999999995
# Solución: ([1528822987, 1554813465, 335720315, 1528822981, 1530897844, 550376458, 550376452, 1530897624, 550376456], ' Se recorrio 438.172 metros en 0.8763439999999999 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 313673
# Nodos Expandidos: 205654
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 14
# Coste de la solución: 105.60263999999997
# Solución: ([1560900349, 1528181137, 1528181111, 1528181138, 335720304, 335720305, 335720308, 1554813465, 335720315, 1528822981, 1530897844, 550376458, 550376452, 1530897624, 550376456], ' Se recorrio 880.022 metros en 1.7600440000000004 minutos')
# Clave no encontrada: 1557262702
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 313718
# Nodos Expandidos: 205684
# Tiempo de ejecucion: 0.013849735260009766
# Longitud de la solución: 15
# Coste de la solución: 64.37507999999998
# Solución: ([1554807214, 1572435237, 1572435249, 1574598070, 1572435255, 1554807113, 1526105986, 618009048, 1530209368, 550376433, 1574608089, 1530897496, 1530897950, 550376452, 1530897624, 550376456], ' Se recorrio 536.459 metros en 1.072918 minutos')
# Clave no encontrada: 1560897811
# No hay solucion
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 313719
# Nodos Expandidos: 205685
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 0
# Coste de la solución: 0
# Solución: []
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 313723
# Nodos Expandidos: 205687
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 2
# Coste de la solución: 4.5072
# Solución: ([550376452, 1530897624, 550376456], ' Se recorrio 37.56 metros en 0.07512 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 313765
# Nodos Expandidos: 205714
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 9
# Coste de la solución: 63.45683999999999
# Solución: ([335720305, 335720308, 1554813465, 335720315, 1528822981, 1530897844, 550376458, 550376452, 1530897624, 550376456], ' Se recorrio 528.807 metros en 1.057614 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 313817
# Nodos Expandidos: 205748
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 17
# Coste de la solución: 63.12399999999999
# Solución: ([1526105983, 1530209339, 335720312, 335607957, 335607958, 335896858, 335896877, 335720310, 1560897796, 550378434, 1991970566, 550376433, 1574608089, 1530897496, 1530897950, 550376452, 1530897624, 550376456], ' Se recorrio 532.9200000000001 metros en 1.0520666666666667 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 313848
# Nodos Expandidos: 205766
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 6
# Coste de la solución: 31.680719999999997
# Solución: ([335720315, 1528822981, 1530897844, 550376458, 550376452, 1530897624, 550376456], ' Se recorrio 264.00600000000003 metros en 0.5280119999999999 minutos')
# Clave no encontrada: 1557262702
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 313893
# Nodos Expandidos: 205796
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 11
# Coste de la solución: 47.01635999999999
# Solución: ([1572435255, 1554807113, 1526105986, 618009048, 1530209368, 550376433, 1574608089, 1530897496, 1530897950, 550376452, 1530897624, 550376456], ' Se recorrio 391.803 metros en 0.7836059999999999 minutos')
# Clave no encontrada: 1557262702
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 313938
# Nodos Expandidos: 205826
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 12
# Coste de la solución: 61.086959999999976
# Solución: ([1526106002, 1526105938, 1554807113, 1526105986, 618009048, 1530209368, 550376433, 1574608089, 1530897496, 1530897950, 550376452, 1530897624, 550376456], ' Se recorrio 509.058 metros en 1.0181159999999998 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 313979
# Nodos Expandidos: 205853
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 10
# Coste de la solución: 49.85027999999999
# Solución: ([1574608082, 1560897869, 1991970573, 1991970566, 550376433, 1574608089, 1530897496, 1530897950, 550376452, 1530897624, 550376456], ' Se recorrio 415.41900000000004 metros en 0.830838 minutos')
# Clave no encontrada: 1835353347
# Clave no encontrada: 1557262702
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 314019
# Nodos Expandidos: 205880
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 10
# Coste de la solución: 59.05229999999999
# Solución: ([1526105988, 1526105986, 618009048, 1530209368, 550376433, 1574608089, 1530897496, 1530897950, 550376452, 1530897624, 550376456], ' Se recorrio 427.90099999999995 metros en 0.9842049999999998 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 314032
# Nodos Expandidos: 205888
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 7
# Coste de la solución: 30.082319999999996
# Solución: ([1991970566, 550376433, 1574608089, 1530897496, 1530897950, 550376452, 1530897624, 550376456], ' Se recorrio 250.686 metros en 0.5013719999999999 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 314048
# Nodos Expandidos: 205897
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 6
# Coste de la solución: 26.162279999999996
# Solución: ([1528822986, 1527972839, 1530897844, 550376458, 550376452, 1530897624, 550376456], ' Se recorrio 218.019 metros en 0.436038 minutos')
# Clave no encontrada: 1557262702
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 314096
# Nodos Expandidos: 205929
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 15
# Coste de la solución: 61.70435999999998
# Solución: ([1554807109, 1554807205, 1572435249, 1574598070, 1572435255, 1554807113, 1526105986, 618009048, 1530209368, 550376433, 1574608089, 1530897496, 1530897950, 550376452, 1530897624, 550376456], ' Se recorrio 514.203 metros en 1.028406 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 314139
# Nodos Expandidos: 205957
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 13
# Coste de la solución: 97.89419999999997
# Solución: ([1530209348, 1528181116, 1528181138, 335720304, 335720305, 335720308, 1554813465, 335720315, 1528822981, 1530897844, 550376458, 550376452, 1530897624, 550376456], ' Se recorrio 815.785 metros en 1.63157 minutos')
# Clave no encontrada: 1560897811
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 314191
# Nodos Expandidos: 205991
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 16
# Coste de la solución: 54.095559999999985
# Solución: ([1530209339, 335720312, 335607957, 335607958, 335896858, 335896877, 335720310, 1560897796, 550378434, 1991970566, 550376433, 1574608089, 1530897496, 1530897950, 550376452, 1530897624, 550376456], ' Se recorrio 457.68300000000005 metros en 0.9015926666666667 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 314202
# Nodos Expandidos: 205997
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 5
# Coste de la solución: 9.83208
# Solución: ([1574608089, 1530897496, 1530897950, 550376452, 1530897624, 550376456], ' Se recorrio 81.934 metros en 0.163868 minutos')
# Clave no encontrada: 1557262702
# Clave no encontrada: 1835353347
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 314249
# Nodos Expandidos: 206028
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 14
# Coste de la solución: 55.22327999999999
# Solución: ([1554807205, 1572435249, 1574598070, 1572435255, 1554807113, 1526105986, 618009048, 1530209368, 550376433, 1574608089, 1530897496, 1530897950, 550376452, 1530897624, 550376456], ' Se recorrio 460.194 metros en 0.9203879999999999 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 314291
# Nodos Expandidos: 206055
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 13
# Coste de la solución: 100.62719999999997
# Solución: ([1528181137, 1528181111, 1528181138, 335720304, 335720305, 335720308, 1554813465, 335720315, 1528822981, 1530897844, 550376458, 550376452, 1530897624, 550376456], ' Se recorrio 838.5600000000001 metros en 1.6771200000000004 minutos')
# Clave no encontrada: 1528181129
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 314336
# Nodos Expandidos: 206084
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 16
# Coste de la solución: 115.80731999999998
# Solución: ([1528181122, 1574608077, 1560900349, 1528181137, 1528181111, 1528181138, 335720304, 335720305, 335720308, 1554813465, 335720315, 1528822981, 1530897844, 550376458, 550376452, 1530897624, 550376456], ' Se recorrio 965.061 metros en 1.9301220000000001 minutos')
# Resultados también descargados en un archivo txt llamado Resultadotxt.txt
# Problema:Calle Agustina Aroca, Albacete
# Nodos Generados: 314337
# Nodos Expandidos: 206084
# Tiempo de ejecucion: 0.0
# Longitud de la solución: 0
# Coste de la solución: 0
# Solución: ([550376456], ' Se recorrio 0 metros en 0 minutos')
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[80], line 3
#       1 BusquedaAL = BusquedaAleatoria(r"C:\Users\ramon\Desktop\Archivos uni\4 año\Inteligentes\Practica2\calle_agustina_aroca_albacete_250_0_candidates_75_ns_7.json")
# ----> 3 BusquedaAL.Bus(69,10)
#       5 # BusquedaAL = AlgoritmoGenetico(r"C:\Users\Ana Barberá\Desktop\Práctica 2 Algoritmos metaheurísicos-20241215\sample-problems-lab2\medium\calle_agustina_aroca_albacete_500_1_candidates_89_ns_22.json")
#       6 # BusquedaAL.BusA(69)
#       7
#       8 # BusquedaMA = hill_climbing(r"C:\Users\Ana Barberá\Desktop\Práctica 2 Algoritmos metaheurísicos-20241215\sample-problems-lab2\medium\calle_agustina_aroca_albacete_500_1_candidates_89_ns_22.json")
#       9 # BusquedaMA.Bus(69, 1000)
#
# Cell In[77], line 68, in BusquedaAleatoria.Bus(self, sem, n)
#      66                 sIds.append(self.problema.iDCandidates[i])
#      67                 continue
# ---> 68             vIds[i] = [0,self.problema.iDCandidates[i]]
#      69         valor = self.EsSolucion(sIds)
#      71 fin = time.time()
#
# IndexError: list assignment index out of range
